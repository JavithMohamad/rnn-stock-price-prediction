# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras import layers
from keras.models import Sequential

# %%
dataset_train = pd.read_csv('trainset.csv')

# %%
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dataset_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-02  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  2013-01-03  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  2013-01-04  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  2013-01-07  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  2013-01-08  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900

# %%
train_set = dataset_train.iloc[:,1:2].values

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
train_set.shape
# Out:
# (1259, 1)

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
training_set_scaled.shape
# Out:
# (1259, 1)

# %%
X_train_array = []
y_train_array = []
for i in range(60, 1259):
  X_train_array.append(training_set_scaled[i-60:i,0])
  y_train_array.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train_array), np.array(y_train_array)
X_train1 = X_train.reshape((X_train.shape[0], X_train.shape[1],1))

# %%
X_train.shape
# Out:
# (1199, 60)

# %%
length = 60
n_features = 1

# %%
model = Sequential()
model.add(layers.SimpleRNN(50,input_shape=(length,n_features)))
model.add(layers.Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
print("Name: JAVITH.M       Register Number:212222110014 ")
model.summary()
# Out:
# Name: JAVITH.M       Register Number:212222110014
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 2651 (10.36 KB)
# Trainable params: 2651 (10.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train1,y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 20ms/step - loss: 0.0117
# Epoch 2/100
# 38/38 [==============================] - 1s 21ms/step - loss: 7.8961e-04
# Epoch 3/100
# 38/38 [==============================] - 1s 20ms/step - loss: 6.9031e-04
# Epoch 4/100
# 38/38 [==============================] - 1s 19ms/step - loss: 5.8921e-04
# Epoch 5/100
# 38/38 [==============================] - 1s 15ms/step - loss: 5.6472e-04
# Epoch 6/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.8222e-04
# Epoch 7/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.8993e-04
# Epoch 8/100
# 38/38 [==============================] - 0s 11ms/step - loss: 5.4041e-04
# Epoch 9/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.3585e-04
# Epoch 10/100
# 38/38 [==============================] - 0s 12ms/step - loss: 5.2095e-04
# Epoch 11/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.6380e-04
# Epoch 12/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.1152e-04
# Epoch 13/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.9754e-04
# Epoch 14/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.0124e-04
# Epoch 15/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.0672e-04
# Epoch 16/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.8658e-04
# Epoch 17/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.1770e-04
# Epoch 18/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.4702e-04
# Epoch 19/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.9180e-04
# Epoch 20/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.4490e-04
# Epoch 21/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.7447e-04
# Epoch 22/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.1612e-04
# Epoch 23/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.6111e-04
# Epoch 24/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.2476e-04
# Epoch 25/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.1957e-04
# Epoch 26/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.4099e-04
# Epoch 27/100
# 38/38 [==============================] - 1s 14ms/step - loss: 3.1779e-04
# Epoch 28/100
# 38/38 [==============================] - 1s 18ms/step - loss: 3.3543e-04
# Epoch 29/100
# 38/38 [==============================] - 1s 18ms/step - loss: 3.1533e-04
# Epoch 30/100
# 38/38 [==============================] - 1s 19ms/step - loss: 3.0025e-04
# Epoch 31/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.9037e-04
# Epoch 32/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.9495e-04
# Epoch 33/100
# 38/38 [==============================] - 1s 16ms/step - loss: 2.9189e-04
# Epoch 34/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.0586e-04
# Epoch 35/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.7502e-04
# Epoch 36/100
# 38/38 [==============================] - 1s 15ms/step - loss: 2.6857e-04
# Epoch 37/100
# 38/38 [==============================] - 1s 15ms/step - loss: 2.6626e-04
# Epoch 38/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.9820e-04
# Epoch 39/100
# 38/38 [==============================] - 1s 25ms/step - loss: 2.7441e-04
# Epoch 40/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.8400e-04
# Epoch 41/100
# 38/38 [==============================] - 1s 25ms/step - loss: 2.6745e-04
# Epoch 42/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.6044e-04
# Epoch 43/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.5573e-04
# Epoch 44/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.6384e-04
# Epoch 45/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.3603e-04
# Epoch 46/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.5037e-04
# Epoch 47/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.3126e-04
# Epoch 48/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.2501e-04
# Epoch 49/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.2762e-04
# Epoch 50/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.6603e-04
# Epoch 51/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.5583e-04
# Epoch 52/100
# 38/38 [==============================] - 1s 13ms/step - loss: 3.2893e-04
# Epoch 53/100
# 38/38 [==============================] - 1s 20ms/step - loss: 2.3403e-04
# Epoch 54/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.5256e-04
# Epoch 55/100
# 38/38 [==============================] - 1s 20ms/step - loss: 2.4548e-04
# Epoch 56/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.4491e-04
# Epoch 57/100
# 38/38 [==============================] - 1s 20ms/step - loss: 2.2515e-04
# Epoch 58/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1285e-04
# Epoch 59/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.2014e-04
# Epoch 60/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.2957e-04
# Epoch 61/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.4512e-04
# Epoch 62/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0397e-04
# Epoch 63/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.3391e-04
# Epoch 64/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.0020e-04
# Epoch 65/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.6825e-04
# Epoch 66/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.7115e-04
# Epoch 67/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0900e-04
# Epoch 68/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1775e-04
# Epoch 69/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9611e-04
# Epoch 70/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0005e-04
# Epoch 71/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1203e-04
# Epoch 72/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1180e-04
# Epoch 73/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.1640e-04
# Epoch 74/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0936e-04
# Epoch 75/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1042e-04
# Epoch 76/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8339e-04
# Epoch 77/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9072e-04
# Epoch 78/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8561e-04
# Epoch 79/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8620e-04
# Epoch 80/100
# 38/38 [==============================] - 1s 18ms/step - loss: 1.8215e-04
# Epoch 81/100
# 38/38 [==============================] - 1s 19ms/step - loss: 1.7908e-04
# Epoch 82/100
# 38/38 [==============================] - 1s 20ms/step - loss: 2.0814e-04
# Epoch 83/100
# 38/38 [==============================] - 1s 19ms/step - loss: 1.8855e-04
# Epoch 84/100
# 38/38 [==============================] - 1s 19ms/step - loss: 1.8058e-04
# Epoch 85/100
# 38/38 [==============================] - 1s 19ms/step - loss: 1.7201e-04
# Epoch 86/100
# 38/38 [==============================] - 1s 13ms/step - loss: 1.6908e-04
# Epoch 87/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9268e-04
# Epoch 88/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.0140e-04
# Epoch 89/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7464e-04
# Epoch 90/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9107e-04
# Epoch 91/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8039e-04
# Epoch 92/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8893e-04
# Epoch 93/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7974e-04
# Epoch 94/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.6955e-04
# Epoch 95/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9943e-04
# Epoch 96/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8346e-04
# Epoch 97/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7439e-04
# Epoch 98/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8145e-04
# Epoch 99/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8908e-04
# Epoch 100/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7543e-04

# %%
dataset_test = pd.read_csv('testset.csv')

# %%
test_set = dataset_test.iloc[:,1:2].values

# %%
test_set.shape
# Out:
# (125, 1)

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis=0)

# %%
inputs = dataset_total.values
inputs = inputs.reshape(-1,1)
inputs_scaled=sc.transform(inputs)
X_test = []
y_test = []
for i in range(60,1384):
  X_test.append(inputs_scaled[i-60:i,0])
  y_test.append(inputs_scaled[i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
X_test.shape
# Out:
# (1324, 60, 1)

# %%
predicted_stock_price_scaled = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price_scaled)
# Out:
# 42/42 [==============================] - 0s 5ms/step

# %%
print("Name:JAVITH .M           Register Number:212222110014")
plt.plot(np.arange(0,1384),inputs, color='red', label = 'Test(Real) Google stock price')
plt.plot(np.arange(60,1384),predicted_stock_price, color='blue', label = 'Predicted Google stock price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# Name:JAVITH .M           Register Number:212222110014

# %%
from sklearn.metrics import mean_squared_error as mse
mse = mse(y_test,predicted_stock_price)
print("Mean squared Error : ",mse)
# Out:
# Mean squared Error :  537615.941766872
